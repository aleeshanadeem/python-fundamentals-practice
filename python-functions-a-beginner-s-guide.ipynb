# %% [markdown]
# <div style="
#   display:inline-block;          /* full width nahi lega */
#   border-left:6px solid #8e24aa;
#   border-right:6px solid #8e24aa;
#   background:#f9f2ff;
#   padding:6px 16px;
#   margin:10px 0;
#   border-radius:30px;
#   font-family:Segoe UI, Arial, sans-serif;
#   color:#2c2c2c;
#   text-align:center;
# ">
#
#   <p style="margin:6px 0;">
#     <span style="color:#1565c0;font-weight:600;">Author:</span>
#     <span style="color:#2e7d32;font-weight:600;">Aleesha Nadeem</span>
#   </p>
#
# </div>
#
# <div style="
#   width: 420px;
#   margin: 40px auto;
#   padding: 18px 25px;
#   border-radius: 14px;
#   background: linear-gradient(135deg, #1e3a8a, #0ea5e9);
#   box-shadow: 0 10px 25px rgba(0,0,0,0.18);
#   text-align: center;
#   font-family: 'Segoe UI', Arial, sans-serif;
# ">
#
#   <h1 style="
#     margin:0;
#     font-size:26px;
#     font-weight:700;
#     color:#ffffff;
#   ">
#     Basic Python Functions for Beginners
#   </h1>
#
#   <p style="
#     margin-top:10px;
#     font-size:15px;
#     color:#e0f2fe;
#     text-align:center;
#   ">
#     A Step-by-Step Guide to Creating and Using Python Functions
#     with Simple Examples, Explanation and Practice.
#   </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: #f8fafc;
#     border-left: 6px solid #2563eb;
#     padding: 22px 26px;
#     border-radius: 10px;
#     font-family: Arial, sans-serif;
#     box-shadow: 0 8px 20px rgba(0,0,0,0.08);
# ">
#
# <h1 style="
#     margin-top: 0;
#     margin-bottom: 14px;
#     font-size: 26px;
#     color: #1e293b;
#     font-weight: 800;
# ">
# Introduction
# </h1>
#
# <p style="color:#334155; font-size:15px; line-height:1.7;">
# This notebook focuses on one of the most powerful and essential concepts in <strong>Python programming: Functions</strong>. The main goal of this notebook is to clearly understand how Python functions work and why they are so important in real programming. Instead of simply memorizing syntax, this notebook explores the logic and structure behind functions and how they help in building efficient programs.
# </p>
#
# <p style="color:#334155; font-size:15px; line-height:1.7;">
# In this notebook, I will explore the key concepts of <strong>Python Functions,</strong> including:
#
# - <strong>What is a Function</strong>
# - <strong>Why Functions are used</strong>
# - <strong>How to define Functions using def</strong>
# - <strong>Function Parameters and Arguments</strong>
# - <strong>Return Statements</strong>
# - <strong>Types of Function </strong>
# - <strong>Lambda Functions</strong>
#
# - <strong>Recursion</strong>
# </p>
#
# <p style="color:#334155; font-size:15px; line-height:1.7;">
# Each concept will be explained using a <strong>simple structure:</strong>
#
# <strong>What  •  Why  •  How  •  Use  •  Example  •  Code</strong>
#
# This approach helps in understanding not only the syntax but also the practical purpose of functions in programming.
#
# Understanding functions is an important step for writing modular and scalable code. Functions are widely used in <strong>data analysis, automation, software development, and machine learning workflows.</strong>
#
# This notebook is part of my learning journey toward becoming a <strong>Data Scientist</strong>, where mastering <strong>Python fundamentals</strong> plays a crucial role before moving to advanced topics like data analysis, machine learning, and artificial intelligence.
#
# <strong>Let’s start exploring the power of Python functions. 🚀</strong>
# </p>
#
# </div>

# %% [markdown]
# <div style="
#       display:inline-block;          /* full width nahi lega */
#   background:#D0D0F7;
#   border-left:5px solid #0505B5;
# border-right:5px solid #0505B5;
#   padding:12px 16px;
#   border-radius:8px;
#   font-family:Arial, sans-serif;
#   box-shadow:0 6px 14px rgba(0,0,0,0.06);
#   margin-top:10px;
# ">
#
# <h3 style="
#   margin:6px 0;
#   font-size:16px;
#   color:#1C1C1F;
#   font-weight:700;
# ">
# Start.........
# </h3>
#
# <p style="
#   margin:4px 0;
#   font-size:13px;
#   color:#475569;
# ">
# </p>

# %% [markdown]
# **1️⃣ What:**
#
# A function is a reusable block of code that performs a **specific task**. Instead of writing the same code **again and again**, we can place the **logic inside** a function and call it whenever needed.
#
#  **2️⃣   Why:**
#
# Function are ***important*** used in Programming:
#
# *  Code Reusability
# *  Better Organization
# *  Easier Debugging
# *  Improved Readability
# *  Modularity
#
#   **3️⃣ How:**
#
# A python fuction create to used ***def(*Defination*)*** Keyword
#
# **4️⃣ Structure:**
#
#
# ![images (5).jfif](attachment:a0150cb6-750d-4363-91b7-70bc441ebb5b.jfif)
#
# **5️⃣ Table:**
#
# <div style="
# border:2px solid #6c63ff;
# border-radius:10px;
# padding:15px;
# background-color:#f9f9ff;
# width:80%;
# ">
#
# <table style="width:100%; border-collapse: collapse; font-family:Arial;">
# <tr style="background-color:#A3B2E6;">
# <th style="padding:8px; border:1px solid #ddd;">Part</th>
# <th style="padding:8px; border:1px solid #ddd;">Meaning</th>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>def</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Keyword used to define a function</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>function_name</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Name of the function</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>parameters</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Inputs the function receives</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>argument</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Calling the function </td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>return</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Sends the result back</td>
# </tr>
#
# </table>
# </div>
#
# \n
#
#
# **5️⃣ Example:**
#
#
# ***Problem_1***
#
# Create a function that name a user.
#
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>INPUT:</strong>
# </span>

# %%
def author(name): ## Define_function(def)
    return  name
    ## Calling_function 
    print(author("Aleesha"))

# %% [markdown]
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>OUTPUT:</strong>
# </span>
#
#
# Aleesha

# %% [markdown]
# <h1 style="
#   display: inline-block;   /* box ko sirf text tak limit karta hai */
#   font-family: Arial, sans-serif;
#   font-size: 22px;         /* thora chhota size */
#   font-weight: 500;
#   color: #ffffff;
#   background: linear-gradient(135deg, #CFAEA5, #1e40af);
#   padding: 8px 14px;      /* kam padding = chhota box */
#   border-radius: 14px;
#   box-shadow: 0 4px 12px rgba(0,0,20,0.35);
#   margin: 10px 0;
# ">
#   🔹 Explanation:
# </h1>

# %% [markdown]
# * **author():** is a function_name
#
# * **name:** is the parameter
#
# * **Aleesha:** is the argument

# %% [markdown]
# <h1 style="
#   display: inline-block;   /* box ko sirf text tak limit karta hai */
#   font-family: Arial, sans-serif;
#   font-size: 22px;         /* thora chhota size */
#   font-weight: 500;
#   color: #EDEFF5;
#   background: linear-gradient(135deg, #8396DE, #1e40af);
#   padding: 8px 14px;      /* kam padding = chhota box */
#   border-radius: 14px;
#   box-shadow: 0 4px 12px rgba(0,0,20,0.35);
#   margin: 10px 0;
# ">
#   🔹 Types of Function
# </h1>
#
# **There are Two type of Function:**
#
# ![download (7).jfif](attachment:fdff9ad3-a6f9-4238-a5e6-c5cd37e7eb84.jfif)
#
#  ### 1. Built-in Functions:
#
#   These functions are ***already*** available in Python.
#
# - print()
# - len()
# - type()
# - sum()
#
# #### Explanation
#
# <div style="
# border:2px solid #4CAF50;
# border-radius:10px;
# padding:15px;
# background-color:#f8fff8;
# width:85%;
# ">
#
# <table style="width:100%; border-collapse: collapse; font-family:Arial;">
#
# <tr style="background-color:#e6ffe6;">
# <th style="padding:10px; border:1px solid #ddd;">Function</th>
# <th style="padding:10px; border:1px solid #ddd;">Description</th>
# <th style="padding:10px; border:1px solid #ddd;">Example</th>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>print()</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Used to display output on the screen. It is one of the most commonly used Python built-in functions.</td>
# <td style="padding:8px; border:1px solid #ddd;">print("Hello World")</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>len()</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Returns the number of items in an object such as a list, string, or tuple.</td>
# <td style="padding:8px; border:1px solid #ddd;">len([1,2,3,4])</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>type()</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Used to check the data type of a variable or value.</td>
# <td style="padding:8px; border:1px solid #ddd;">type(10)</td>
# </tr>
#
# <tr>
# <td style="padding:8px; border:1px solid #ddd;"><b>Range()/sum()</b></td>
# <td style="padding:8px; border:1px solid #ddd;">Calculates the total sum of numbers in an iterable like a list or tuple.</td>
# <td style="padding:8px; border:1px solid #ddd;">sum([10,20,30])</td>
# </tr>
#
# </table>
#
# </div>
#
# ### 2.User_Defined Functions:
#
# These functions are ***created*** by programmers/user.
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Example_1:</strong>
# </span>

# %%
## function_defination
def add_numbers(a,b):
    return a + b
    ## function_calling
print("OUTPUT:")
print(add_numbers(2,2))
# Out:
# OUTPUT:
# 4

# %% [markdown]
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Example_2:</strong>
# </span>

# %%
## function_defination
def add_numbers(a, b):
    return a + b
    ## function_calling
print("OUTPUT:")
print(add_numbers("Zubaira⚡", "Aleesha"))
# Out:
# OUTPUT:
# Zubaira⚡Aleesha

# %% [markdown]
# <div style="font-family: Arial, sans-serif; margin:20px 0;">
# <h2 style="color:#2563eb;">Argument vs Parameter in Python</h2>
#
# <table style="border-collapse: collapse; width:100%; text-align:left;">
# <tr style="background:#3b82f6; color:white;">
# <th style="padding:10px; border:1px solid #ddd;">Feature</th>
# <th style="padding:10px; border:1px solid #ddd;">Parameter</th>
# <th style="padding:10px; border:1px solid #ddd;">Argument</th>
# </tr>
#
# <tr style="background:#f8fafc;">
# <td style="padding:10px; border:1px solid #ddd;"><b>Description</b></td>
# <td style="padding:10px; border:1px solid #ddd;">A variable defined in a function to receive a value.</td>
# <td style="padding:10px; border:1px solid #ddd;">The actual value passed to the function when it is called.</td>
# </tr>
#
# <tr>
# <td style="padding:10px; border:1px solid #ddd;"><b>When it is used</b></td>
# <td style="padding:10px; border:1px solid #ddd;">When the function is defined.</td>
# <td style="padding:10px; border:1px solid #ddd;">When the function is called.</td>
# </tr>
#
# <tr style="background:#f8fafc;">
# <td style="padding:10px; border:1px solid #ddd;"><b>Example</b></td>
# <td style="padding:10px; border:1px solid #ddd;">def greet(name): → name is a parameter</td>
# <td style="padding:10px; border:1px solid #ddd;">greet("Scientist") → "Scientist" is an argument</td>
# </tr>
#
# <tr>
# <td style="padding:10px; border:1px solid #ddd;"><b>Code Example</b></td>
# <td style="padding:10px; border:1px solid #ddd;">
# <code>def add(a, b):<br> &nbsp;&nbsp;print(a + b)</code>
# </td>
# <td style="padding:10px; border:1px solid #ddd;">
# <code>add(5, 3)</code>
# </td>
# </tr>
#
# <tr style="background:#f8fafc;">
# <td style="padding:10px; border:1px solid #ddd;"><b>Explanation</b></td>
# <td style="padding:10px; border:1px solid #ddd;">a and b are parameters that receive values.</td>
# <td style="padding:10px; border:1px solid #ddd;">5 and 3 are arguments passed to the parameters.</td>
# </tr>
#
# </table>
# </div>

# %% [markdown]
# <h1 style="
#   display: inline-block;   /* box ko sirf text tak limit karta hai */
#   font-family: Arial, sans-serif;
#   font-size: 22px;         /* thora chhota size */
#   font-weight: 500;
#   color: #EDEFF5;
#   background: linear-gradient(135deg, #8396DE, #1e40af);
#   padding: 8px 14px;      /* kam padding = chhota box */
#   border-radius: 14px;
#   box-shadow: 0 4px 12px rgba(0,0,20,0.35);
#   margin: 10px 0;
# ">
#   🔹 Data Structure
# </h1>
#
# **That is a Structure Function Parameter and Argument**
#
#
# ![images.png](attachment:89bd7d08-6c64-4ac7-a93e-94341c7bf8f0.png)

# %% [markdown]
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Example:</strong>
# </span>

# %%
def greet(name):   # name = parameter
    print("Hello", name)
print("OUTPUT:")
greet("Scientist")       # "Scientist" = argument
# Out:
# OUTPUT:
# Hello Scientist

# %% [markdown]
# <h1 style="
#   display: inline-block;   /* box ko sirf text tak limit karta hai */
#   font-family: Arial, sans-serif;
#   font-size: 22px;         /* thora chhota size */
#   font-weight: 500;
#   color: #ffffff;
#   background: linear-gradient(135deg, #CFAEA5, #1e40af);
#   padding: 8px 14px;      /* kam padding = chhota box */
#   border-radius: 14px;
#   box-shadow: 0 4px 12px rgba(0,0,20,0.35);
#   margin: 10px 0;
# ">
#   7️⃣ Return Statement
# </h1>

# %% [markdown]
# The return statement sends the ***result*** of the function ***back*** to the caller(calling_function).
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Structure:</strong>
# </span>
#
# ![images (5).jfif](attachment:0109c44f-3732-47a0-bdd9-a150f7ae804e.jfif)
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Example:</strong>
# </span>

# %%
print("OUTPUT:")
def square(number):
    return number * number
result = square(6)
print(result)
# Out:
# OUTPUT:
# 36

# %% [markdown]
# <div style="
# display:inline-block;          /* full width nahi lega */
# border-left:6px solid #8e24aa;
#   background:#f9f2ff;
#   padding:18px 12px;
#   margin:10px 0;
#   border-radius:20px;
#   font-family:Segoe UI, Arial, sans-serif;
#   color:#2c2c2c;
#   text-align:center;
# ">
#   <h1 style="margin:0 0 0px;color:#4a148c;">Lambda Function</h1>

# %% [markdown]
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>What:</strong>
# </span>
# A Lambda function is a **small anonymous function** in Python that can have any number of arguments but only **one expression**. Unlike normal functions, lambda functions do not **require a name**.
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Keyword:</strong>
# </span>
#   There are defined using the lambda keyword.
#
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Why:</strong>
# </span>
#   Lambda functions are useful when we need a ***simple function*** for a ***short period*** of time. Instead of writing a full function using def, we can write it in one line.
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Advantages:</strong>
# </span>
#
#   1. Reduces code length
#   2. Useful for quick operations
#   3. Often used with functions like map(), filter(), and sorted()
#
# * **Syntax:**
#
# ![download (8).jfif](attachment:7904a2c7-92ef-41e3-9796-5195d1df61ce.jfif)
#
# <span style="
#   font-family: Arial, sans-serif;
#   font-size: 14px;
#   color: #2563eb;
#   font-weight: 600;
# ">
# <strong>Example_1:</strong>
# </span>

# %%
print("OUTPUT:")
def square(x):
    return x * x
square = lambda x: x * x ##lambda_function
print(square(5))
# Out:
# OUTPUT:
# 25

# %% [markdown]
# <div style="
# border-left:6px solid #6c63ff;
# background:linear-gradient(135deg,#f3f2ff,#ffffff);
# padding:18px;
# border-radius:10px;
# font-family:Arial;
# box-shadow:0 4px 10px rgba(0,0,0,0.08);
# ">
#
# <h3 style="color:#4b47c3;">Conclusion</h3>
#
# <p style="font-size:14px; line-height:1.6;">
# In this notebook, we explored the core concept of <b>Python Functions</b> and how they help make code more structured, reusable, and efficient. Understanding functions is a key step toward writing clean programs and building strong foundations for <b>Data Analysis, Data Science, Machine Learning, and AI</b>.
# </p>
#
# <p style="font-size:14px;">
# If you found this notebook helpful:
# <br>
# ⭐ <b>Please consider upvoting</b>
# <br>
# 💬 <b>Share your feedback or suggestions in the comments</b>
# </p>
#
# </div>

# %% [markdown]
# <div style="
#       display:inline-block;          /* full width nahi lega */
#   background:#D0D0F7;
#   border-left:5px solid #0505B5;
# border-right:5px solid #0505B5;
#   padding:12px 16px;
#   border-radius:8px;
#   font-family:Arial, sans-serif;
#   box-shadow:0 6px 14px rgba(0,0,0,0.06);
#   margin-top:10px;
# ">
#
# <h3 style="
#   margin:6px 0;
#   font-size:16px;
#   color:#1C1C1F;
#   font-weight:700;
# ">
# Thank You</h3>
